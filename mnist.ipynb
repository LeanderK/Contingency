# %% [markdown]
# # setup:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_roc(i, fpr, tpr, roc_auc):
    plt.figure()
    lw = 2
    plt.plot(fpr[i], tpr[i], color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
import tensorflow as tf
from augmentation import augmentation, augmentation_data
from augmentation.mnist import mnist
import numpy as np
import augmentation.augmentation 
# Training Parameters
learning_rate = 0.001
num_steps = 200
batch_size = 128

# number of classes trained on
num_classes = 2
num_adversarial = 10 #how many adversarial examples should be generated (if any) per iteration
num_adversarial_train = 5 # how many iterations for the adversarial
# Out:
# /Users/LeanderK/Documents/ML/contingency/venv/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# numer of products 13689
# calculating max dist, i: 0  time elapsed since start:  0:04:30.893207
# calculating max dist, i: 200  time elapsed since start:  0:08:53.749277
# calculating max dist, i: 400  time elapsed since start:  0:12:57.551446
# calculating max dist, i: 600  time elapsed since start:  0:17:01.125876
# calculating max dist, i: 800  time elapsed since start:  0:21:02.113616
# calculating max dist, i: 1000  time elapsed since start:  0:25:23.414625
# calculating max dist, i: 1200  time elapsed since start:  0:29:44.193839
# ...

# %% [markdown]
# # with augmentations:

# %%
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
(fpr, tpr, roc_auc, pred, model) = mnist.run(mnistAug.withoutAugmentation, learning_rate, num_adversarial, mnistAug, batch_size, num_steps)
plot_roc(0, fpr, tpr, roc_auc)
# Out:
# Training Accuracy in iteration  0 : 0.828125
# Training Accuracy in iteration  50 : 1.0
# Training Accuracy in iteration  100 : 1.0
# Training Accuracy in iteration  150 : 1.0
# Final Accuracy on only valid classes: 0.999656
# Final Accuracy on unexpected data: 0.537603
# Final Accuracy on random data: 0.0518799

# %%
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
(fpr, tpr, roc_auc, pred, model) = mnist.run(mnistAug.with_augmentation, learning_rate, num_adversarial, mnistAug, batch_size, num_steps)
plot_roc(0, fpr, tpr, roc_auc)
# Out:
# Training Accuracy in iteration  0 : 0.429688
# Training Accuracy in iteration  50 : 1.0
# Training Accuracy in iteration  100 : 1.0
# Training Accuracy in iteration  150 : 1.0
# Final Accuracy on only valid classes: 0.99957
# Final Accuracy on unexpected data: 0.649334
# Final Accuracy on random data: 1.0

# %%
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
(fpr, tpr, roc_auc, pred, model) = mnist.run(mnistAug.with_random_augmentation, learning_rate, num_adversarial, mnistAug, batch_size, num_steps)
plot_roc(0, fpr, tpr, roc_auc)
# Out:
# Training Accuracy in iteration  0 : 0.429688
# Training Accuracy in iteration  50 : 1.0
# Training Accuracy in iteration  100 : 1.0
# Training Accuracy in iteration  150 : 1.0
# Final Accuracy on only valid classes: 0.999398
# Final Accuracy on unexpected data: 0.68142
# Final Accuracy on random data: 1.0

# %% [markdown]
# # pre-trained models

# %%
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
def runAndSave(): 
    (images, labels, is_training) = mnist.set_up(mnistAug)
    aug_data_obj = mnistAug.getAugmentationData()
    with tf.Session() as session:
        model = mnistAug.withoutAugmentation(learning_rate, images, labels, is_training)
        saver = tf.train.Saver()
        summary_writer = tf.summary.FileWriter('tensorboard/train',
                                            session.graph)
        session.run(tf.global_variables_initializer())
        session.run(tf.tables_initializer())
        session.run(tf.local_variables_initializer())

        for iteration in range(num_steps):
            (aug_data, aug_lbls) = model['train_fn'](iteration, session, batch_size, batch_size)
            # a = session.run(accEval, feed_dict={images.name: train_im, labels.name: train_la})
            if iteration % 50 == 0:
                (test_data, test_lbls) = aug_data_obj.next_test_batch(batch_size)
                feed_dict = {images: test_data, labels: test_lbls, is_training.name: False}
                mnist.summarize(session, model, feed_dict, iteration, summary_writer)
        save_path = saver.save(session, "savedModels/model.ckpt")
        return (mnistAug.eval(session, model, images, labels, is_training), save_path)
(roc_stuff, save_path) = runAndSave()
plot_roc(0, roc_stuff[0], roc_stuff[1], roc_stuff[2])
# Out:
# Training Accuracy in iteration  0 : 0.429688
# Training Accuracy in iteration  50 : 1.0
# Training Accuracy in iteration  100 : 1.0
# Training Accuracy in iteration  150 : 1.0
# Final Accuracy on only valid classes: 0.999828
# Final Accuracy on unexpected data: 0.677362
# Final Accuracy on random data: 0.793943

# %%
#save_path = 'savedModels/model.ckpt'

# %%
#check if loading works
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
def runAndSave(): 
    (images, labels, is_training) = mnist.set_up(mnistAug)
    aug_data_obj = mnistAug.getAugmentationData()
    with tf.Session() as session:
        model = mnistAug.only_random_augmentation(learning_rate, images, labels, is_training)
        variables = tf.trainable_variables(scope='^ConvNet/.*')
        saver = tf.train.Saver(variables)
        summary_writer = tf.summary.FileWriter('tensorboard/train',
                                            session.graph)
        session.run(tf.global_variables_initializer())
        session.run(tf.tables_initializer())
        session.run(tf.local_variables_initializer())
        saver.restore(session, save_path)
        for iteration in range(num_steps):
            (aug_data, aug_lbls) = model['train_fn'](iteration, session, batch_size, batch_size)
            # a = session.run(accEval, feed_dict={images.name: train_im, labels.name: train_la})
            if iteration % 50 == 0:
                (test_data, test_lbls) = aug_data_obj.next_test_batch(batch_size)
                feed_dict = {images: test_data, labels: test_lbls, is_training.name: False}
                mnist.summarize(session, model, feed_dict, iteration, summary_writer)
        return (mnistAug.eval(session, model, images, labels, is_training), save_path)
(roc_stuff, save_path) = runAndSave()
plot_roc(0, roc_stuff[0], roc_stuff[1], roc_stuff[2])
# Out:
# INFO:tensorflow:Restoring parameters from savedModels/model.ckpt
# Training Accuracy in iteration  0 : 1.0
# Training Accuracy in iteration  50 : 0.382812
# Training Accuracy in iteration  100 : 0.476562
# Training Accuracy in iteration  150 : 0.4375
# Final Accuracy on only valid classes: 0.468382
# Final Accuracy on unexpected data: 1.0
# Final Accuracy on random data: 1.0

# %%
#check if loading works
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
def runAndSave(): 
    (images, labels, is_training) = mnist.set_up(mnistAug)
    aug_data_obj = mnistAug.getAugmentationData()
    with tf.Session() as session:
        model = mnistAug.only_augmentation(learning_rate, images, labels, is_training)
        variables = tf.trainable_variables(scope='^ConvNet/.*')
        saver = tf.train.Saver(variables)
        summary_writer = tf.summary.FileWriter('tensorboard/train',
                                            session.graph)
        session.run(tf.global_variables_initializer())
        session.run(tf.tables_initializer())
        session.run(tf.local_variables_initializer())
        saver.restore(session, save_path)
        for iteration in range(num_steps):
            (aug_data, aug_lbls) = model['train_fn'](iteration, session, batch_size, batch_size)
            # a = session.run(accEval, feed_dict={images.name: train_im, labels.name: train_la})
            if iteration % 50 == 0:
                (test_data, test_lbls) = aug_data_obj.next_test_batch(batch_size)
                feed_dict = {images: test_data, labels: test_lbls, is_training.name: False}
                mnist.summarize(session, model, feed_dict, iteration, summary_writer)
        return (mnistAug.eval(session, model, images, labels, is_training), save_path)
(roc_stuff, save_path) = runAndSave()
plot_roc(0, roc_stuff[0], roc_stuff[1], roc_stuff[2])
# Out:
# INFO:tensorflow:Restoring parameters from savedModels/model.ckpt
# Training Accuracy in iteration  0 : 1.0
# Training Accuracy in iteration  50 : 0.382812
# Training Accuracy in iteration  100 : 0.476562
# Training Accuracy in iteration  150 : 0.4375
# Final Accuracy on only valid classes: 0.468382
# Final Accuracy on unexpected data: 1.0
# Final Accuracy on random data: 1.0

# %% [markdown]
# # random stuff:

# %%
#check if loading works
tf.reset_default_graph()
augData = mnist.MNISTAugData(num_classes)
gen = augmentation.augmentation.Augmentation.gen_labels_default_class(num_classes, 0)
mnistAug = mnist.MNISTAugmentation(learning_rate, num_adversarial, num_adversarial_train, augData, gen)
def runAndSave(): 
    (images, labels, is_training) = mnist.set_up(mnistAug)
    aug_data_obj = mnistAug.getAugmentationData()
    with tf.Session() as session:
        model = mnistAug.withoutAugmentation(learning_rate, images, labels, is_training)
        saver = tf.train.Saver()
        summary_writer = tf.summary.FileWriter('tensorboard/train',
                                            session.graph)
        session.run(tf.global_variables_initializer())
        session.run(tf.tables_initializer())
        session.run(tf.local_variables_initializer())
        saver.restore(session, save_path)
        return (mnistAug.eval(session, model, images, labels, is_training), save_path)
(roc_stuff, save_path) = runAndSave()
plot_roc(0, roc_stuff[0], roc_stuff[1], roc_stuff[2])
# Out:
# INFO:tensorflow:Restoring parameters from savedModels/model.ckpt
# Final Accuracy on only valid classes: 0.999828
# Final Accuracy on unexpected data: 0.672796
# Final Accuracy on random data: 0.993547

# %%
(test_img, test_lbls) = cont_data.next_test_batch(10)
(unexp_img, unexp_lbls) = cont_data.unexpected_data()
unexp_img = unexp_img[:10]
unexp_lbls = unexp_lbls[:10]
with tf.Session() as session:
    (acc_test, pred_test) = session.run(
                    [model['acc_op'], model['pred_op']], 
                    feed_dict={'images:0': test_img, 'labels:0': test_lbls, 'is_training:0': False}
                )
    (acc_unexp, pred_unexp) = session.run(
                    [model['acc_op'], model['pred_op']], 
                    feed_dict={'images:0': unexp_img, 'labels:0': unexp_lbls, 'is_training:0': False}
                )
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# ~/Documents/ML/contingency/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# ~/Documents/ML/contingency/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# ~/Documents/ML/contingency/venv/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# ...
